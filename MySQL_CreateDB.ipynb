# %%
#建立MySQL資料庫
import pymysql
conn = pymysql.connect(host='localhost',port=3306,user='root',passwd='55688',charset='utf8',db='pythondb01')

with conn.cursor() as cursor:
    sql = """
    CREATE TABLE IF NOT EXISTS 投資理財書目 (
    ID               int NOT NULL AUTO_INCREMENT PRIMARY KEY,
    Name             varchar(200),
    Writer           varchar(20),
    Publishing_house varchar(10),
    Publish_date     varchar(10),
    Price            varchar(10),
    Special_price    varchar(10)
    );
    """
    cursor.execute(sql)
    conn.commit()
conn.close()               #用uniServer看結果檢查

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#插入資料
import pymysql
conn = pymysql.connect(host='localhost',port=3306,user='root',passwd='55688',charset='utf8',db='pythondb01')

with conn.cursor() as cursor:
    sql = """
    INSERT INTO 投資理財書目 (Name,Writer,Publishing_house,Publish_date,Price,Special_price) values
    ('隱市致富地圖：60億操盤手用一張圖，找到上漲超過30％的翻轉人生贏勢股','股市隱者','大是文化','2022/03/29','420元','79折332元'),
    ('致富本命：隱形富豪教我的12堂「不缺」財商課，學會靠本業起家，用斜槓投資致富-用6,000元啟動財富正循環，改寫人生！','陳韋翰','大牌出版','2022/04/13','380元','79折300元'),
    ('有錢人買的股票和你不一樣：韓國前1%富豪御用操盤人首度揭露富人不說，卻默默都在用的選股祕訣','金賢俊','樂金文化','2022/04/13','420元','79折332元'),
    ('給存股新手的財富翻滾筆記【隨書附贈：存股新手SOP小冊】：最適合小資族的「金融股543規律」，用薪水4萬輕鬆打造年收股息20萬！','小車X存股實驗','幸福文化','2022/03/16','380元','79折300元'),
    ('財富自由的整理鍊金術：斷捨離變身金錢魔法，打造心靈×空間×時間×財務自由人生！','整理鍊金術師小印','遠流','2022/03/30','340元','79折269元'),
    ('別在該理財的年紀，選擇放棄','崴爺','博思智庫','2022/03/01','320元','79折253元'),
    ('懂錢滾錢：打造最強個人財務系統，美國「預算天后」改造100萬人的財富指引','蒂芙尼‧阿里奇','大牌出版','2022/01/25','480元','79折379元'),
    ('灰階思考','謝孟恭','天下文化','2021/04/20','400元','79折316元'),
    ('跟著柴鼠學FQ，做自己的提款機：為投資理財打好基本功，讓你不靠勞力，增加被動收入，快速FIRE','柴鼠兄弟','采實文化','2020/03/26','380元','79折300元'),
    ('投資上癮：人氣Podcast節目「投資癮」製作人，教你突破交易心魔，設計自己的投資遊戲','簡瑋德','商周出版','2021/11/06','400元','79折316元')
    ;
    """
    cursor.execute(sql)
    conn.commit()
conn.close()               #用uniServer看結果檢查

# %% [markdown]
# ![image.png](attachment:image.png)
